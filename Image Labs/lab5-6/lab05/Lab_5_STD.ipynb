# %% [markdown]
# # Lab 5
# ### Edge Detection
#
# https://github.com/scikit-image/scikit-image/blob/master/skimage/filters/edges.py
#
# http://scikit-image.org/docs/0.11.x/auto_examples/plot_edge_filter.html
#
# http://scikit-image.org/docs/dev/auto_examples/edges/plot_canny.html

# %%
from commonfunctions import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
'''
1. Built-in Sobel, Prewill, Roberts
2. Custom Sobel (V-H-Both)
3. Custom LoG
'''
img=io.imread('circuit.tif')
imgGray=rgb2gray(img)
edges = ([],[])
edges[0].append(sobel(imgGray))
edges[0].append(sobel_v(imgGray))
edges[0].append(sobel_h(imgGray))
#show_images([imgGray,edgesB,edgesV,edgesH],["gray","Both","Vertical","Horizontal"])
edges[0].append(prewitt(imgGray))
edges[0].append(roberts(imgGray))
edges[0].append(canny(imgGray))
edges[1].append("SobelB")
edges[1].append("SobelV")
edges[1].append("sobelH")
edges[1].append("prewitt")
edges[1].append("roberts")
edges[1].append("canny")
show_images(edges[0],edges[1])



vFilter=np.array([
    [-1,0,1],
    [-2,0,2],
    [-1,0,1]
])
hFilter=np.transpose(vFilter)
convV=convolve2d(img,vFilter)
convH=convolve2d(img,hFilter)
#edge45 = np.tan((convV / convH))
result=(np.power(np.power(convV,2)+np.power(convH,2),0.5)>80).astype(float)
show_images([convV,convH,result, edge45],["v","h","result"])
#1. Built-in Sobel, Prewill, Roberts

# 2. Custom Sobel (V-H-Both)

# 3. Custom LoG
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in tan
